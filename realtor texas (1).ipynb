# %% [markdown]
# ### Imports

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import sqlalchemy
import urllib.parse

# %% [markdown]
# ### HTTP Request

# %% [markdown]
# #### store website in variable

# %%
header = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0.0.0 Safari/537.36'}

website = 'https://www.realtor.com/realestateandhomes-search/Texas'

# %% [markdown]
# #### Get Request

# %%
response = requests.get(website, headers=header)

# %% [markdown]
# #### Status Code

# %%
response
# Out:
# <Response [200]>

# %% [markdown]
# ### Soup Object

# %%
soup = BeautifulSoup(response.content, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
# <html lang="en"><head><meta charset="utf-8"/><script>window.kxdl = { jy: '' };  window.rdcdl = window.kxdl;  !function(n,e,i){if(!n){n=n||{},window.permutive=n,n.q=[],n.config=i||{},n.config.apiKey=e,n.config.environment=n.config.environment||'production';for(var o=['addon','identify','track','trigger','query','segment','segments','ready','on','once','user','consent'],r=0;r<o.length;r++){var t=o[r];n[t]=function(e){return function(){var i=Array.prototype.slice.call(arguments,0);n.q.push({functionName:e,arguments:i})}}(t)}}}(window.permutive,'2336e88c-2653-4e72-9d49-c562730fd85f',{});(function(g,o){g[o]=g[o]||function(){(g[o]['q']=g[o]['q']||[]).push(arguments)},g[o]['t']=1*new Date})(window,'_googCsa');</script><script async="" data-testid="dfp" fetchpriority="auto" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js"></script><script async="" data-testid="prebid" fetchpriority="auto" src="https://pbcs.realtor.com/p/realtor/realtor/pb.js"></script><script async="" data-testid="amazon" fetchpriority="auto" src="https://c.amazon-adsystem.com/aax2/apstag.js"></script><script async="" data-testid="permutive" fetchpriority="auto" src="https://0cf17917-395b-4f25-91cc-db3bdd6044b0.edge.permutive.app/5dc35e4e-c442-405b-bf5f-5c2b8824b0cf-web.js"></script><script async="" data-testid="openwrap" fetchpriority="auto" src="https://ads.pubmatic.com/AdServer/js/pwt/162281/7793/pwt.js"></script><script async="" data-testid="adsense" fetchpriority="auto" src="https://www.google.com/adsense/search/ads.js"></script><script async="" data-testid="adlightning" fetchpriority="auto" src="https://tagan.adlightning.com/realtor/op.js"></script><title>Texas Real Estate &amp; TX Homes for Sale | realtor.com®</title><link href="https://www.realtor.com/realestateandhomes-search/Texas" rel="canonical"/><meta content="Search TX real estate at realtor.com®. View property details of the 218403 homes for sale in Texas." name="description"/><meta content="https://www.realtor.com/realestateandhomes-search/Texas" property="og:url"/><meta content="Texas Real Estate &amp; TX Homes for Sale | realtor.com®" property="og:title"/><meta content="Search TX real estate at realtor.com®. View property details of the 218403 homes for sale in Texas." property="og:description"/><meta content="https://ap.rdcpix.com/0876627cf9b4eefadbf3c28cd22bcdb6l-m2446876104od-w480_h480_q80.jpg" property="og:image"/><meta content="realtor.com®" property="og:site_name"/><meta content="Search TX real estate at realtor.com®. View property details of the 218403 homes for sale in Texas." property="twitter:description"/><meta content="https://ap.rdcpix.com/0876627cf9b4eefadbf3c28cd22bcdb6l-m2446876104od-w480_h480_q80.jpg" property="twitter:image"/><meta content="@realtordotcom" name="twitter:site"/><meta content="website" property="og:type"/><meta content="480" property="og:image:width"/><meta content="480" property="og:image:height"/><meta content="rdc-x-web-cube/v2.8" name="app-version"/><meta content="false" data-useragent="Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0.0.0 Safari/537.36" name="isbot"/><meta content="width=device-width, initial-scale=1, maximum-scale=1" name="viewport"/><link as="image" href="https://ap.rdcpix.com/0876627cf9b4eefadbf3c28cd22bcdb6l-m2446876104od-w480_h360_x2.webp" rel="preload" type="image/webp"/><link as="image" href="https://ap.rdcpix.com/542f0a4c38a33cfbcde7630b30f3143al-m3721137363od-w480_h360_x2.webp" rel="preload" type="image/webp"/><link as="image" href="https://ap.rdcpix.com/efd6c191a6188948a1712ed844401bcel-m2753172657od-w480_h360_x2.webp" rel="preload" type="image/webp"/><meta content="22" name="next-head-count"/><link crossorigin="true" href="https://cdn.optimizely.com" rel="preconnect"/><link href="https://static.rdc.moveaws.com/touch-icon.png" rel="touch-icon"/><link href="https://static.rdc.moveaws.com/favicon.ico" rel="icon"/><script>window.NREUM||(NREUM={});NREUM.info = {"agent":"","beacon":"bam.n ...
# (()=>{"use strict";var e,t,r={5763:(e,t,r)=>{r.d(t,{P_:()=>f,Mt:()=>p,C5:()=>s,DL:()=>v,OP:()=>T,lF:()=>D,Yu:()=>y,Dg:()=>h,CX:()=>c,GE:()=>b,sU:()=>_});var n=r(8632),i=r(9567);const o={beacon:n.ce.beacon,errorBeacon:n.ce.errorBeacon,licenseKey:void 0,applicationID:void 0,sa:void 0,queueTime:void 0,applicationTime:void 0,ttGuid:void 0,user:void 0,account:void 0,product:void 0,extra:void 0,jsAttributes:{},userAttributes:void 0,atts:void 0,transactionName:void 0,tNamePlain:void 0},a={};function s(e){if(!e)throw new Error("All info objects require an agent identifier!");if(!a[e])throw new Error("Info for ".concat(e," was never set"));return a[e]}function c(e,t){if(!e)throw new Error("All info objects require an agent identifier!");a[e]=(0,i.D)(t,o),(0,n.Qy)(e,a[e],"info")}var u=r(7056);const d=()=>{const e={blockSelector:"[data-nr-block]",maskInputOptions:{password:!0}};return{allow_bfcache:!0,privacy:{cookies_enabled:!0},ajax:{deny_list:void 0,block_internal:!0,enabled:!0,harvestTimeSeconds:10},distributed_tracing:{enabled:void 0,exclude_newrelic_header:void 0,cors_use_newrelic_header:void 0,cors_use_tracecontext_headers:void 0,allowed_origins:void 0},session:{domain:void 0,expiresMs:u.oD,inactiveMs:u.Hb},ssl:void 0,obfuscate:void 0,jserrors:{enabled:!0,harvestTimeSeconds:10},metrics:{enabled:!0},page_action:{enabled:!0,harvestTimeSeconds:30},page_view_event:{enabled:!0},page_view_timing:{enabled:!0,harvestTimeSeconds:30,long_task:!1},session_trace:{enabled:!0,harvestTimeSeconds:10},harvest:{tooManyRequestsDelay:60},session_replay:{enabled:!1,harvestTimeSeconds:60,sampleRate:.1,errorSampleRate:.1,maskTextSelector:"*",maskAllInputs:!0,get blockClass(){return"nr-block"},get ignoreClass(){return"nr-ignore"},get maskTextClass(){return"nr-mask"},get blockSelector(){return e.blockSelector},set blockSelector(t){e.blockSelector+=",".concat(t)},get maskInputOptions(){return e.maskInputOptions},set maskInputOptions(t){e.maskInputOptions={...t,password:!0}}},spa:{enabled:!0,harvestTimeSeconds:10}}},l={};function f(e){if(!e)throw new Error("All configuration objects require an agent identifier!");if(!l[e])throw new Error("Configuration for ".concat(e," was never set"));return l[e]}function h(e,t){if(!e)throw new Error("All configuration objects require an agent identifier!");l[e]=(0,i.D)(t,d()),(0,n.Qy)(e,l[e],"config")}function p(e,t){if(!e)throw new Error("All configuration objects require an agent identifier!");var r=f(e);if(r){for(var n=t.split("."),i=0;i<n.length-1;i++)if("object"!=typeof(r=r[n[i]]))return;r=r[n[n.length-1]]}return r}const g={accountID:void 0,trustKey:void 0,agentID:void 0,licenseKey:void 0,applicationID:void 0,xpid:void 0},m={};function v(e){if(!e)throw new Error("All loader-config objects require an agent identifier!");if(!m[e])throw new Error("LoaderConfig for ".concat(e," was never set"));return m[e]}function b(e,t){if(!e)throw new Error("All loader-config objects require an agent identifier!");m[e]=(0,i.D)(t,g),(0,n.Qy)(e,m[e],"loader_config")}const y=(0,n.mF)().o;var w=r(385),A=r(6818);const x={buildEnv:A.Re,bytesSent:{},queryBytesSent:{},customTransaction:void 0,disabled:!1,distMethod:A.gF,isolatedBacklog:!1,loaderType:void 0,maxBytes:3e4,offset:Math.floor(w._A?.performance?.timeOrigin||w._A?.performance?.timing?.navigationStart||Date.now()),onerror:void 0,origin:""+w._A.location,ptid:void 0,releaseIds:{},session:void 0,xhrWrappable:"function"==typeof w._A.XMLHttpRequest?.prototype?.addEventListener,version:A.q4,denyList:void 0},E={};function T(e){if(!e)throw new Error("All runtime objects require an agent identifier!");if(!E[e])throw new Error("Runtime for ".concat(e," was never set"));return E[e]}function _(e,t){if(!e)throw new Error("All runtime objects require an agent identifier!");E[e]=(0,i.D)(t,x),(0,n.Qy)(e,E[e],"runtime")}function D(e){return function(e){try{const t=s(e);return!!t.licenseKey&&!!t.errorBeacon&&!!t.applicationID}catch(e){return!1}}(e)}},9567:(e,t,r)=>{r.d(t,{D:()=>i});var n=r(50);function ...
# .cxYOPm[type='number']::-webkit-inner-spin-button,.cxYOPm[type='number']::-webkit-outer-spin-button{margin:0;}/*!sc*/
# data-styled.g1[id="InputElement-rui__kzcwvy-0"]{content:"cxYOPm,"}/*!sc*/
# .biHnzR{box-shadow:0 0 0 1px #757575 inset;border-radius:8px;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-box-flex:1;-webkit-flex-grow:1;-ms-flex-positive:1;flex-grow:1;max-width:100%;min-height:40px;-webkit-transition:border-color 100ms cubic-bezier(0.5,0,0.2,1);transition:border-color 100ms cubic-bezier(0.5,0,0.2,1);background-color:#FFFFFF;}/*!sc*/
# data-styled.g2[id="InputGroup-rui__hn7d6j-0"]{content:"biHnzR,"}/*!sc*/
# .dytNJW{display:inline-block;width:-webkit-max-content;width:-moz-max-content;width:max-content;}/*!sc*/
# data-styled.g3[id="Popperstyles__PopperAnchorWrapper-rui__sc-1tp3q5v-0"]{content:"dytNJW,"}/*!sc*/
# .kjUHJl{background-color:transparent;background-image:none;border:0;cursor:pointer;height:16px;overflow:hidden;padding:calc(calc(16px / 2) + 14px);position:relative;width:16px;}/*!sc*/
# .kjUHJl:before,.kjUHJl:after{background-color:#FFFFFF;content:' ';height:16px;position:absolute;top:14px;width:2px;}/*!sc*/
# .kjUHJl:before{-webkit-transform:rotate(45deg);-ms-transform:rotate(45deg);transform:rotate(45deg);}/*!sc*/
# .kjUHJl:after{-webkit-transform:rotate(-45deg);-ms-transform:rotate(-45deg);transform:rotate(-45deg);}/*!sc*/
# @media (hover:hover) and (pointer:fine){.kjUHJl:hover:before,.kjUHJl:hover:after{background-color:#DFDFDF;}}/*!sc*/
# .kjUHJl:focus:before,.kjUHJl:focus:after{background-color:#DFDFDF;}/*!sc*/
# .kXfrQp{background-color:transparent;background-image:none;border:0;cursor:pointer;height:24px;overflow:hidden;padding:calc(calc(24px / 2) + 14px);position:relative;width:24px;}/*!sc*/
# .kXfrQp:before,.kXfrQp:after{background-color:#2B2B2B;content:' ';height:24px;position:absolute;top:14px;width:2px;}/*!sc*/
# .kXfrQp:before{-webkit-transform:rotate(45deg);-ms-transform:rotate(45deg);transform:rotate(45deg);}/*!sc*/
# .kXfrQp:after{-webkit-transform:rotate(-45deg);-ms-transform:rotate(-45deg);transform:rotate(-45deg);}/*!sc*/
# @media (hover:hover) and (pointer:fine){.kXfrQp:hover:before,.kXfrQp:hover:after{background-color:#646464;}}/*!sc*/
# .kXfrQp:focus:before,.kXfrQp:focus:after{background-color:#646464;}/*!sc*/
# .cbCmXZ{background-color:transparent;background-image:none;border:0;cursor:pointer;height:20px;overflow:hidden;padding:calc(calc(20px / 2) + 14px);position:relative;width:20px;}/*!sc*/
# .cbCmXZ:before,.cbCmXZ:after{background-color:#2B2B2B;content:' ';height:20px;position:absolute;top:14px;width:2px;}/*!sc*/
# .cbCmXZ:before{-webkit-transform:rotate(45deg);-ms-transform:rotate(45deg);transform:rotate(45deg);}/*!sc*/
# .cbCmXZ:after{-webkit-transform:rotate(-45deg);-ms-transform:rotate(-45deg);transform:rotate(-45deg);}/*!sc*/
# @media (hover:hover) and (pointer:fine){.cbCmXZ:hover:before,.cbCmXZ:hover:after{background-color:#646464;}}/*!sc*/
# .cbCmXZ:focus:before,.cbCmXZ:focus:after{background-color:#646464;}/*!sc*/
# data-styled.g7[id="styles__StyledCloseButton-rui__z6l2vv-0"]{content:"kjUHJl,kXfrQp,cbCmXZ,"}/*!sc*/
# .hhZQzR{font-size:12px;line-height:16px;font-weight:700;text-align:inherit;color:#FFFFFF;}/*!sc*/
# @media (max-width:767px){.hhZQzR{font-weight:700;}}/*!sc*/
# .eRRmbh{font-size:14px;line-height:inherit;font-weight:500;text-align:inherit;color:#2B2B2B;}/*!sc*/
# @media (max-width:767px){.eRRmbh{line-height:inherit;font-weight:500;}}/*!sc*/
# .mvAUu{font-size:14px;line-height:20px;font-weight:700;text-align:inherit;color:#2B2B2B;}/*!sc*/
# @media (max-width:767px){.mvAUu{font-weight:700;}}/*!sc*/
# .hyPBXg{font-size:14px;line-height:20px;font-weight:400;text-align:inherit;color:#2B2B2B;white-space:nowrap;overflow:hidden;text-overflow:ellipsis;}/*!sc*/
# .gCzmlw{font-size:14px;line-height:20px;font-weight:400;text-align:inherit;color:#2B2B2B;margin-bottom:8px;}/*!sc*/
# .coGdIm{font-size:14px;line-height:20px;font-weight:400;text-align:inherit;color:#2B2B2B;margin-top:16px;margin-bottom:8px;}/*!sc*/
# .dzWDTf{font-size:16px;line-height:24px;font-weight:400;text-align:inherit;color:#2B2B2B;}/*!sc*/
# .iZQYTO{font-size:16px;line-height:24px;font-weight:400;text-align:inherit;color:#2B2B2B;white-space:nowrap;overflow:hidden;text-overflow:ellipsis;}/*!sc*/
# .kpUjhd{font-size:14px;line-height:20px;font-weight:400;text-align:inherit;color:#2B2B2B;}/*!sc*/
# .iAbDCa{font-size:20px;line-height:32px;-webkit-letter-spacing:0.6px;-moz-letter-spacing:0.6px;-ms-letter-spacing:0.6px;letter-spacing:0.6px;font-weight:700;text-align:inherit;color:#2B2B2B;}/*!sc*/
# @media (max-width:767px){.iAbDCa{font-size:18px;line-height:24px;-webkit-letter-spacing:0.6px;-moz-letter-spacing:0.6px;-ms-letter-spacing:0.6px;letter-spacing:0.6px;font-weight:700;}}/*!sc*/
# .loCKQc{font-size:16px;line-height:24px;font-weight:700;text-align:inherit;color:#2B2B2B;}/*!sc*/
# @media (max-width:767px){.loCKQc{font-weight:700;}}/*!sc*/
# .kpqWov{font-size:20px;line-height:32px;-webkit-letter-spacing:0.6px;-moz-letter-spacing:0.6px;-ms-letter-spacing:0.6px;letter-spacing:0.6px;font-weight:700;text-align:inherit;color:#2B2B2B;margin-bottom:8px;}/*!sc*/
# @media (max-width:767px){.kpqWov{font-size:18px;line-height:24px;-webkit-letter-spacing:0.6px;-moz-letter-spacing:0.6px;-ms-letter-spacing:0.6px;letter-spacing:0.6px;font-weight:700;}}/*!sc*/
# .klRdja{font-size:18px;line-height:24px;font-weight:700;text-align:inherit;color:#2B2B2B;}/*!sc*/
# @media (max-width:767px){.klRdja{font-weight:700;}}/*!sc*/
# .fWgYAL{font-size:14px;line-height:20px;font-weight:400;text-align:inherit;color:#2B2B2B;margin-bottom:16px;}/*!sc*/
# .bSZnAh{font-size:16px;line-height:24px;font-weight:700;text-align:inherit;color:#2B2B2B;}/*!sc*/
# @media (max-width:767px){.bSZnAh{font-size:16px;font-weight:700;}}/*!sc*/
# .ezenPO{font-size:14px;line-height:20px;font-weight:400;text-align:inherit;color:#2B2B2B;}/*!sc*/
# @media (max-width:767px){.ezenPO{font-weight:400;}}/*!sc*/
# .iOBDUi{font-size:20px;line-height:32px;-webkit-letter-spacing:0.6px;-moz-letter-spacing:0.6px;-ms-letter-spacing:0.6px;letter-spacing:0.6px;font-weight:700;text-align:inherit;color:#FFFFFF;}/*!sc*/
# @media (max-width:767px){.iOBDUi{font-size:18px;line-height:24px;-webkit-letter-spacing:0.6px;-moz-letter-spacing:0.6px;-ms-letter-spacing:0.6px;letter-spacing:0.6px;font-weight:700;}}/*!sc*/
# .dBGWku{font-size:12px;line-height:16px;font-weight:400;text-align:inherit;color:#2B2B2B;}/*!sc*/
# data-styled.g8[id="base__StyledType-rui__sc-108xfm0-0"]{content:"hhZQzR,eRRmbh,mvAUu,hyPBXg,gCzmlw,coGdIm,dzWDTf,iZQYTO,kpUjhd,iAbDCa,loCKQc,kpqWov,klRdja,fWgYAL,bSZnAh,ezenPO,iOBDUi,dBGWku,"}/*!sc*/
# .eXwOuc{color:#2B2B2B;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;margin-bottom:4px;margin-top:0;}/*!sc*/
# .eXwOuc .label-hint{display:block;position:relative;height:20px;width:20px;z-index:15001;}/*!sc*/
# .eXwOuc .label-hint svg{left:50%;position:absolute;top:50%;-webkit-transform:translate(-50%,-50%);-ms-transform:translate(-50%,-50%);transform:translate(-50%,-50%);}/*!sc*/
# .ffBhEX{color:#2B2B2B;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;margin-bottom:4px;margin-top:0;cursor:pointer;}/*!sc*/
# .ffBhEX .label-hint{display:block;position:relative;height:20px;width:20px;z-index:15001;}/*!sc*/
# .ffBhEX .label-hint svg{left:50%;position:absolute;top:50%;-webkit-transform:translate(-50%,-50%);-ms-transform:translate(-50%,-50%);transform:translate(-50%,-50%);}/*!sc*/
# data-styled.g9[id="Label__StyledLabel-rui__sc-1by3ei1-0"]{content:"eXwOuc,ffBhEX,"}/*!sc*/
# .bszylW:not(.focusable),.bszylW.focusable:not(:focus):not(:focus-within){position:absolute !important;width:1px !important;height:1px !important;padding:0 !important;margin:-1px !important;overflow:hidden !important;-webkit-clip:rect(0,0,0,0) !important;clip:rect(0,0,0,0) !important;border:0 !important;white-space:nowrap !important;word-wrap:normal !important;}/*!sc*/
# data-styled.g11[id="VisuallyHiddenstyles__StyledVisuallyHidden-rui__aoql8k-0"]{content:"bszylW,"}/*!sc*/
# .dYVSYa{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;}/*!sc*/
# .dYVSYa label{font-size:14px;}/*!sc*/
# data-styled.g12[id="LabelWrapperstyles__StyledLabelWrapper-rui__xiucf9-0"]{content:"dYVSYa,"}/*!sc*/
# .jQGjNK{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;color:#757575;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;margin-top:4px;}/*!sc*/
# .jQGjNK .helper-text-error-icon{-webkit-align-self:flex-start;-ms-flex-item-align:start;align-self:flex-start;-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;margin:0 4px 4px 0;margin-top:2px;}/*!sc*/
# data-styled.g14[id="FormHelperTextstyles__StyledFormHelperText-rui__sc-1rbcmi4-0"]{content:"jQGjNK,"}/*!sc*/
# .fzYqku{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;background-color:#FFFFFF;box-shadow:0px -1px 0px #757575 inset,0px 1px 0px #757575 inset,1px 0px 0px #757575 inset;border:none;color:#2B2B2B;cursor:default;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;padding:7px 12px;position:relative;-webkit-transition:border-color 100ms cubic-bezier(0.5,0,0.2,1);transition:border-color 100ms cubic-bezier(0.5,0,0.2,1);z-index:0;border-top-left-radius:8px;border-bottom-left-radius:8px;padding-right:8px;}/*!sc*/
# .fETwCk{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;background-color:#FFFFFF;box-shadow:0px -1px 0px #757575 inset,0px 1px 0px #757575 inset,-1px 0px 0px #757575 inset;border:none;color:#2B2B2B;cursor:pointer;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;padding:7px 12px;position:relative;-webkit-transition:border-color 100ms cubic-bezier(0.5,0,0.2,1);transition:border-color 100ms cubic-bezier(0.5,0,0.2,1);z-index:0;border-top-right-radius:8px;border-bottom-right-radius:8px;padding-left:8px;}/*!sc*/
# data-styled.g15[id="InputAddonstyles__StyledInputAddon-rui__sc-1rthqly-0"]{content:"fzYqku,fETwCk,"}/*!sc*/
# .iFzAmv{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-box-flex:1;-webkit-flex-grow:1;-ms-flex-positive:1;flex-grow:1;position:relative;}/*!sc*/
# .iFzAmv .InputGroup-rui__hn7d6j-0{box-shadow:0px -1px 0px #757575 inset,0px 1px 0px #757575 inset;border-top-left-radius:0;border-bottom-left-radius:0;border-top-right-radius:0;border-bottom-right-radius:0;}/*!sc*/
# .iFzAmv .InputAddonstyles__StyledInputAddon-rui__sc-1rthqly-0{gap:8px;z-index:2;}/*!sc*/
# .kcFtAJ{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-box-flex:1;-webkit-flex-grow:1;-ms-flex-positive:1;flex-grow:1;position:relative;}/*!sc*/
# .kcFtAJ .InputGroup-rui__hn7d6j-0{border-top-left-radius:8px;border-bottom-left-radius:8px;border-top-right-radius:8px;border-bottom-right-radius:8px;}/*!sc*/
# .kcFtAJ .InputAddonstyles__StyledInputAddon-rui__sc-1rthqly-0{gap:8px;z-index:2;}/*!sc*/
# data-styled.g16[id="TextInputstyles__StyledWrapper-rui__sih3wv-0"]{content:"iFzAmv,kcFtAJ,"}/*!sc*/
# .eoSmhW{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;position:relative;}/*!sc*/
# .eoSmhW .InputGroup-rui__hn7d6j-0{padding-left:0;padding-right:0;}/*!sc*/
# .eoSmhW.outline{border-radius:8px;outline:5px auto Highlight;outline:5px auto -webkit-focus-ring-color;}/*!sc*/
# .eoSmhW.outline .InputAddonstyles__StyledInputAddon-rui__sc-1rthqly-0,.eoSmhW.outline .InputGroup-rui__hn7d6j-0{border-color:#757575;}/*!sc*/
# .eoSmhW.outline input{outline:none;}/*!sc*/
# .duxOvy{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;position:relative;}/*!sc*/
# .duxOvy .InputGroup-rui__hn7d6j-0{padding-left:16px;padding-right:16px;}/*!sc*/
# .duxOvy.outline{border-radius:8px;outline:5px auto Highlight;outline:5px auto -webkit-focus-ring-color;}/*!sc*/
# .duxOvy.outline .InputAddonstyles__StyledInputAddon-rui__sc-1rthqly-0,.duxOvy.outline .InputGroup-rui__hn7d6j-0{border-color:#757575;}/*!sc*/
# .duxOvy.outline input{outline:none;}/*!sc*/
# data-styled.g17[id="TextInputstyles__StyledInputWrapper-rui__sih3wv-1"]{content:"eoSmhW,duxOvy,"}/*!sc*/
# .daAHdq{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;background-image:none;cursor:pointer;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;font-weight:500;gap:8px;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;line-height:1;touch-action:manipulation;-webkit-transition:background-color 100ms cubic-bezier(0.5,0,0.2,1),color 100ms cubic-bezier(0.5,0,0.2,1),border-color 100ms cubic-bezier(0.5,0,0.2,1);transition:background-color 100ms cubic-bezier(0.5,0,0.2,1),color 100ms cubic-bezier(0.5,0,0.2,1),border-color 100ms cubic-bezier(0.5,0,0.2,1);-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;vertical-align:middle;font-size:16px;border-radius:40px;border:1px solid transparent;-webkit-text-decoration:none;text-decoration:none;height:36px;border-radius:0;border:0;padding:0;text-align:left;-webkit-text-decoration:underline;text-decoration:underline;color:#2B2B2B;background-color:transparent;border-color:transparent;}/*!sc*/
# .daAHdq.disabled{cursor:not-allowed;}/*!sc*/
# @media (hover:hover) and (pointer:fine){.daAHdq:hover{-webkit-text-decoration:underline;text-decoration:underline;}}/*!sc*/
# .daAHdq:focus{-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .daAHdq:focus:not(:focus-visible){outline:none;}/*!sc*/
# @media (hover:hover) and (pointer:fine){.daAHdq:hover{color:#646464;background-color:transparent;border-color:transparent;}}/*!sc*/
# .daAHdq:focus{color:#2B2B2B;}/*!sc*/
# .daAHdq.active{color:#646464;background-color:transparent;border-color:transparent;}/*!sc*/
# .daAHdq.disabled{color:#A0A0A0;background-color:transparent;border-color:transparent;}/*!sc*/
# .jHcrvF{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;background-image:none;cursor:pointer;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;font-weight:500;gap:8px;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;line-height:1;touch-action:manipulation;-webkit-transition:background-color 100ms cubic-bezier(0.5,0,0.2,1),color 100ms cubic-bezier(0.5,0,0.2,1),border-color 100ms cubic-bezier(0.5,0,0.2,1);transition:background-color 100ms cubic-bezier(0.5,0,0.2,1),color 100ms cubic-bezier(0.5,0,0.2,1),border-color 100ms cubic-bezier(0.5,0,0.2,1);-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;white-space:nowrap;vertical-align:middle;font-size:16px;border-radius:40px;border:1px solid transparent;-webkit-text-decoration:none;text-decoration:none;height:48px;padding:0 24px;margin-left:6px;color:#2B2B2B;background-color:#FFFFFF;border-color:#2B2B2B;}/*!sc*/
# .jHcrvF.disabled{cursor:not-allowed;}/*!sc*/
# .jHcrvF false @media (hover:hover) and (pointer:fine):hover{-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .jHcrvF:focus{-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .jHcrvF:focus:not(:focus-visible){outline:none;}/*!sc*/
# @media (hover:hover) and (pointer:fine){.jHcrvF:hover{color:#646464;background-color:#F2F2F2;border-color:#646464;}}/*!sc*/
# .jHcrvF:focus{color:#2B2B2B;}/*!sc*/
# .jHcrvF.active{color:#2B2B2B;background-color:#F2F2F2;border-color:#2B2B2B;}/*!sc*/
# .jHcrvF.disabled{color:#A0A0A0;background-color:#F2F2F2;border-color:#A0A0A0;}/*!sc*/
# .zxHqB{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;background-image:none;cursor:pointer;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;font-weight:500;gap:8px;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;line-height:1;touch-action:manipulation;-webkit-transition:background-color 100ms cubic-bezier(0.5,0,0.2,1),color 100ms cubic-bezier(0.5,0,0.2,1),border-color 100ms cubic-bezier(0.5,0,0.2,1);transition:background-color 100ms cubic-bezier(0.5,0,0.2,1),color 100ms cubic-bezier(0.5,0,0.2,1),border-color 100ms cubic-bezier(0.5,0,0.2,1);-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;vertical-align:inherit;font-size:inherit;height:auto;-webkit-text-decoration:underline;text-decoration:underline;border-radius:0;border:0;padding:0;text-align:left;-webkit-text-decoration:underline;text-decoration:underline;color:#2B2B2B;background-color:transparent;border-color:transparent;}/*!sc*/
# .zxHqB.disabled{cursor:not-allowed;}/*!sc*/
# @media (hover:hover) and (pointer:fine){.zxHqB:hover{-webkit-text-decoration:underline;text-decoration:underline;}}/*!sc*/
# .zxHqB:focus{-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .zxHqB:focus:not(:focus-visible){outline:none;}/*!sc*/
# @media (hover:hover) and (pointer:fine){.zxHqB:hover{color:#646464;background-color:transparent;border-color:transparent;}}/*!sc*/
# .zxHqB:focus{color:#2B2B2B;}/*!sc*/
# .zxHqB.active{color:#646464;background-color:transparent;border-color:transparent;}/*!sc*/
# .zxHqB.disabled{color:#A0A0A0;background-color:transparent;border-color:transparent;}/*!sc*/
# .rejIS{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;background-image:none;cursor:pointer;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;font-weight:500;gap:8px;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;line-height:1;touch-action:manipulation;-webkit-transition:background-color 100ms cubic-bezier(0.5,0,0.2,1),color 100ms cubic-bezier(0.5,0,0.2,1),border-color 100ms cubic-bezier(0.5,0,0.2,1);transition:background-color 100ms cubic-bezier(0.5,0,0.2,1),color 100ms cubic-bezier(0.5,0,0.2,1),border-color 100ms cubic-bezier(0.5,0,0.2,1);-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;white-space:nowrap;vertical-align:middle;font-size:16px;border-radius:40px;border:1px solid transparent;-webkit-text-decoration:none;text-decoration:none;height:48px;padding:0 24px;color:#2B2B2B;background-color:#FFFFFF;border-color:#2B2B2B;}/*!sc*/
# .rejIS.disabled{cursor:not-allowed;}/*!sc*/
# .rejIS false @media (hover:hover) and (pointer:fine):hover{-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .rejIS:focus{-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .rejIS:focus:not(:focus-visible){outline:none;}/*!sc*/
# @media (hover:hover) and (pointer:fine){.rejIS:hover{color:#646464;background-color:#F2F2F2;border-color:#646464;}}/*!sc*/
# .rejIS:focus{color:#2B2B2B;}/*!sc*/
# .rejIS.active{color:#2B2B2B;background-color:#F2F2F2;border-color:#2B2B2B;}/*!sc*/
# .rejIS.disabled{color:#A0A0A0;background-color:#F2F2F2;border-color:#A0A0A0;}/*!sc*/
# .hjJwHD{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;background-image:none;cursor:pointer;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;font-weight:500;gap:8px;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;line-height:1;touch-action:manipulation;-webkit-transition:background-color 100ms cubic-bezier(0.5,0,0.2,1),color 100ms cubic-bezier(0.5,0,0.2,1),border-color 100ms cubic-bezier(0.5,0,0.2,1);transition:background-color 100ms cubic-bezier(0.5,0,0.2,1),color 100ms cubic-bezier(0.5,0,0.2,1),border-color 100ms cubic-bezier(0.5,0,0.2,1);-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;white-space:nowrap;vertical-align:middle;font-size:16px;border-radius:40px;border:1px solid transparent;-webkit-text-decoration:none;text-decoration:none;height:48px;padding:0 24px;color:#2B2B2B;background-color:#FFFFFF;border-color:#2B2B2B;box-shadow:0px 2px 8px rgba(0,0,0,0.16);}/*!sc*/
# .hjJwHD.disabled{cursor:not-allowed;}/*!sc*/
# .hjJwHD false @media (hover:hover) and (pointer:fine):hover{-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .hjJwHD:focus{-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .hjJwHD:focus:not(:focus-visible){outline:none;}/*!sc*/
# @media (hover:hover) and (pointer:fine){.hjJwHD:hover{color:#2B2B2B;background-color:#F2F2F2;border-color:#2B2B2B;box-shadow:0px 2px 8px rgba(0,0,0,0.16);}}/*!sc*/
# .hjJwHD:focus{color:#2B2B2B;}/*!sc*/
# .hjJwHD.active{color:#2B2B2B;background-color:#F2F2F2;border-color:#2B2B2B;}/*!sc*/
# .hjJwHD.disabled{color:#A0A0A0;background-color:#F2F2F2;border-color:#A0A0A0;box-shadow:none;}/*!sc*/
# .glggPf{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;background-image:none;cursor:pointer;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;font-weight:500;gap:8px;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;line-height:1;touch-action:manipulation;-webkit-transition:background-color 100ms cubic-bezier(0.5,0,0.2,1),color 100ms cubic-bezier(0.5,0,0.2,1),border-color 100ms cubic-bezier(0.5,0,0.2,1);transition:background-color 100ms cubic-bezier(0.5,0,0.2,1),color 100ms cubic-bezier(0.5,0,0.2,1),border-color 100ms cubic-bezier(0.5,0,0.2,1);-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;vertical-align:middle;font-size:16px;border-radius:40px;border:1px solid transparent;-webkit-text-decoration:none;text-decoration:none;height:48px;border-radius:0;border:0;padding:0;text-align:left;-webkit-text-decoration:none;text-decoration:none;color:#FFFFFF;background-color:transparent;border-color:transparent;}/*!sc*/
# .glggPf.disabled{cursor:not-allowed;}/*!sc*/
# @media (hover:hover) and (pointer:fine){.glggPf:hover{-webkit-text-decoration:underline;text-decoration:underline;}}/*!sc*/
# .glggPf:focus{-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .glggPf:focus:not(:focus-visible){outline:none;}/*!sc*/
# @media (hover:hover) and (pointer:fine){.glggPf:hover{color:#F2F2F2;background-color:transparent;border-color:transparent;}}/*!sc*/
# .glggPf:focus{color:#FFFFFF;}/*!sc*/
# .glggPf.active{color:#F2F2F2;background-color:transparent;border-color:transparent;}/*!sc*/
# .glggPf.disabled{color:#A0A0A0;background-color:transparent;border-color:transparent;}/*!sc*/
# .hlouAn{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;background-image:none;cursor:pointer;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;font-weight:500;gap:8px;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;line-height:1;touch-action:manipulation;-webkit-transition:background-color 100ms cubic-bezier(0.5,0,0.2,1),color 100ms cubic-bezier(0.5,0,0.2,1),border-color 100ms cubic-bezier(0.5,0,0.2,1);transition:background-color 100ms cubic-bezier(0.5,0,0.2,1),color 100ms cubic-bezier(0.5,0,0.2,1),border-color 100ms cubic-bezier(0.5,0,0.2,1);-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;vertical-align:middle;font-size:16px;border-radius:40px;border:1px solid transparent;-webkit-text-decoration:none;text-decoration:none;height:48px;border-radius:0;border:0;padding:0;text-align:left;-webkit-text-decoration:underline;text-decoration:underline;color:#FFFFFF;background-color:transparent;border-color:transparent;}/*!sc*/
# .hlouAn.disabled{cursor:not-allowed;}/*!sc*/
# @media (hover:hover) and (pointer:fine){.hlouAn:hover{-webkit-text-decoration:underline;text-decoration:underline;}}/*!sc*/
# .hlouAn:focus{-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .hlouAn:focus:not(:focus-visible){outline:none;}/*!sc*/
# @media (hover:hover) and (pointer:fine){.hlouAn:hover{color:#F2F2F2;background-color:transparent;border-color:transparent;}}/*!sc*/
# .hlouAn:focus{color:#FFFFFF;}/*!sc*/
# .hlouAn.active{color:#F2F2F2;background-color:transparent;border-color:transparent;}/*!sc*/
# .hlouAn.disabled{color:#A0A0A0;background-color:transparent;border-color:transparent;}/*!sc*/
# .iceotV{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;background-image:none;cursor:pointer;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;font-weight:500;gap:8px;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;line-height:1;touch-action:manipulation;-webkit-transition:background-color 100ms cubic-bezier(0.5,0,0.2,1),color 100ms cubic-bezier(0.5,0,0.2,1),border-color 100ms cubic-bezier(0.5,0,0.2,1);transition:background-color 100ms cubic-bezier(0.5,0,0.2,1),color 100ms cubic-bezier(0.5,0,0.2,1),border-color 100ms cubic-bezier(0.5,0,0.2,1);-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;vertical-align:inherit;font-size:inherit;height:auto;-webkit-text-decoration:underline;text-decoration:underline;border-radius:0;border:0;padding:0;text-align:left;-webkit-text-decoration:underline;text-decoration:underline;color:#FFFFFF;background-color:transparent;border-color:transparent;}/*!sc*/
# .iceotV.disabled{cursor:not-allowed;}/*!sc*/
# @media (hover:hover) and (pointer:fine){.iceotV:hover{-webkit-text-decoration:underline;text-decoration:underline;}}/*!sc*/
# .iceotV:focus{-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .iceotV:focus:not(:focus-visible){outline:none;}/*!sc*/
# @media (hover:hover) and (pointer:fine){.iceotV:hover{color:#F2F2F2;background-color:transparent;border-color:transparent;}}/*!sc*/
# .iceotV:focus{color:#FFFFFF;}/*!sc*/
# .iceotV.active{color:#F2F2F2;background-color:transparent;border-color:transparent;}/*!sc*/
# .iceotV.disabled{color:#A0A0A0;background-color:transparent;border-color:transparent;}/*!sc*/
# data-styled.g19[id="base__StyledAnchor-rui__ermeke-0"]{content:"daAHdq,jHcrvF,zxHqB,rejIS,hjJwHD,glggPf,hlouAn,iceotV,"}/*!sc*/
# .hxAKlP{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;background-image:none;cursor:pointer;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;font-weight:500;gap:8px;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;line-height:1;touch-action:manipulation;-webkit-transition:background-color 100ms cubic-bezier(0.5,0,0.2,1),color 100ms cubic-bezier(0.5,0,0.2,1),border-color 100ms cubic-bezier(0.5,0,0.2,1);transition:background-color 100ms cubic-bezier(0.5,0,0.2,1),color 100ms cubic-bezier(0.5,0,0.2,1),border-color 100ms cubic-bezier(0.5,0,0.2,1);-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;vertical-align:inherit;font-size:inherit;height:auto;-webkit-text-decoration:underline;text-decoration:underline;border-radius:0;border:0;padding:0;text-align:left;-webkit-text-decoration:underline;text-decoration:underline;color:#2B2B2B;background-color:transparent;border-color:transparent;}/*!sc*/
# .hxAKlP.disabled{cursor:not-allowed;}/*!sc*/
# @media (hover:hover) and (pointer:fine){.hxAKlP:hover{-webkit-text-decoration:underline;text-decoration:underline;}}/*!sc*/
# .hxAKlP:focus{-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .hxAKlP:focus:not(:focus-visible){outline:none;}/*!sc*/
# @media (hover:hover) and (pointer:fine){.hxAKlP:hover{color:#646464;background-color:transparent;border-color:transparent;}}/*!sc*/
# .hxAKlP:focus{color:#2B2B2B;}/*!sc*/
# .hxAKlP.active{color:#646464;background-color:transparent;border-color:transparent;}/*!sc*/
# .hxAKlP.disabled{color:#A0A0A0;background-color:transparent;border-color:transparent;}/*!sc*/
# .dNiDzg{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;background-image:none;cursor:pointer;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;font-weight:500;gap:8px;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;line-height:1;touch-action:manipulation;-webkit-transition:background-color 100ms cubic-bezier(0.5,0,0.2,1),color 100ms cubic-bezier(0.5,0,0.2,1),border-color 100ms cubic-bezier(0.5,0,0.2,1);transition:background-color 100ms cubic-bezier(0.5,0,0.2,1),color 100ms cubic-bezier(0.5,0,0.2,1),border-color 100ms cubic-bezier(0.5,0,0.2,1);-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;white-space:nowrap;vertical-align:middle;font-size:16px;border-radius:40px;border:1px solid transparent;-webkit-text-decoration:none;text-decoration:none;height:48px;padding:0 24px;color:#2B2B2B;background-color:#FFFFFF;border-color:#2B2B2B;}/*!sc*/
# .dNiDzg.disabled{cursor:not-allowed;}/*!sc*/
# .dNiDzg false @media (hover:hover) and (pointer:fine):hover{-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .dNiDzg:focus{-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .dNiDzg:focus:not(:focus-visible){outline:none;}/*!sc*/
# @media (hover:hover) and (pointer:fine){.dNiDzg:hover{color:#646464;background-color:#F2F2F2;border-color:#646464;}}/*!sc*/
# .dNiDzg:focus{color:#2B2B2B;}/*!sc*/
# .dNiDzg.active{color:#2B2B2B;background-color:#F2F2F2;border-color:#2B2B2B;}/*!sc*/
# .dNiDzg.disabled{color:#A0A0A0;background-color:#F2F2F2;border-color:#A0A0A0;}/*!sc*/
# .ffYpfM{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;background-image:none;cursor:pointer;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;font-weight:500;gap:8px;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;line-height:1;touch-action:manipulation;-webkit-transition:background-color 100ms cubic-bezier(0.5,0,0.2,1),color 100ms cubic-bezier(0.5,0,0.2,1),border-color 100ms cubic-bezier(0.5,0,0.2,1);transition:background-color 100ms cubic-bezier(0.5,0,0.2,1),color 100ms cubic-bezier(0.5,0,0.2,1),border-color 100ms cubic-bezier(0.5,0,0.2,1);-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;white-space:nowrap;vertical-align:middle;font-size:16px;border-radius:40px;border:1px solid transparent;-webkit-text-decoration:none;text-decoration:none;height:48px;padding:0 24px;color:#FFFFFF;background-color:#2B2B2B;border-color:#2B2B2B;}/*!sc*/
# .ffYpfM.disabled{cursor:not-allowed;}/*!sc*/
# .ffYpfM false @media (hover:hover) and (pointer:fine):hover{-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .ffYpfM:focus{-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .ffYpfM:focus:not(:focus-visible){outline:none;}/*!sc*/
# @media (hover:hover) and (pointer:fine){.ffYpfM:hover{color:#FFFFFF;background-color:#646464;border-color:#646464;}}/*!sc*/
# .ffYpfM:focus{color:#FFFFFF;}/*!sc*/
# .ffYpfM.active{color:#FFFFFF;background-color:#646464;border-color:#646464;}/*!sc*/
# .ffYpfM.disabled{color:#A0A0A0;background-color:#F2F2F2;border-color:#A0A0A0;}/*!sc*/
# .dxWNcf{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;background-image:none;cursor:pointer;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;font-weight:500;gap:8px;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;line-height:1;touch-action:manipulation;-webkit-transition:background-color 100ms cubic-bezier(0.5,0,0.2,1),color 100ms cubic-bezier(0.5,0,0.2,1),border-color 100ms cubic-bezier(0.5,0,0.2,1);transition:background-color 100ms cubic-bezier(0.5,0,0.2,1),color 100ms cubic-bezier(0.5,0,0.2,1),border-color 100ms cubic-bezier(0.5,0,0.2,1);-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;white-space:nowrap;vertical-align:middle;font-size:16px;border-radius:40px;border:1px solid transparent;-webkit-text-decoration:none;text-decoration:none;height:48px;padding:0 24px;width:100%;color:#2B2B2B;background-color:#FFFFFF;border-color:#2B2B2B;}/*!sc*/
# .dxWNcf.disabled{cursor:not-allowed;}/*!sc*/
# .dxWNcf false @media (hover:hover) and (pointer:fine):hover{-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .dxWNcf:focus{-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .dxWNcf:focus:not(:focus-visible){outline:none;}/*!sc*/
# @media (hover:hover) and (pointer:fine){.dxWNcf:hover{color:#646464;background-color:#F2F2F2;border-color:#646464;}}/*!sc*/
# .dxWNcf:focus{color:#2B2B2B;}/*!sc*/
# .dxWNcf.active{color:#2B2B2B;background-color:#F2F2F2;border-color:#2B2B2B;}/*!sc*/
# .dxWNcf.disabled{color:#A0A0A0;background-color:#F2F2F2;border-color:#A0A0A0;}/*!sc*/
# .gwvqVZ{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;background-image:none;cursor:pointer;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;font-weight:500;gap:8px;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;line-height:1;touch-action:manipulation;-webkit-transition:background-color 100ms cubic-bezier(0.5,0,0.2,1),color 100ms cubic-bezier(0.5,0,0.2,1),border-color 100ms cubic-bezier(0.5,0,0.2,1);transition:background-color 100ms cubic-bezier(0.5,0,0.2,1),color 100ms cubic-bezier(0.5,0,0.2,1),border-color 100ms cubic-bezier(0.5,0,0.2,1);-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;white-space:nowrap;vertical-align:middle;font-size:16px;border-radius:40px;border:1px solid transparent;-webkit-text-decoration:none;text-decoration:none;height:48px;padding:0 24px;color:#2B2B2B;background-color:#FFFFFF;border-color:#2B2B2B;box-shadow:0px 2px 8px rgba(0,0,0,0.16);}/*!sc*/
# .gwvqVZ.disabled{cursor:not-allowed;}/*!sc*/
# .gwvqVZ false @media (hover:hover) and (pointer:fine):hover{-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .gwvqVZ:focus{-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .gwvqVZ:focus:not(:focus-visible){outline:none;}/*!sc*/
# @media (hover:hover) and (pointer:fine){.gwvqVZ:hover{color:#2B2B2B;background-color:#F2F2F2;border-color:#2B2B2B;box-shadow:0px 2px 8px rgba(0,0,0,0.16);}}/*!sc*/
# .gwvqVZ:focus{color:#2B2B2B;}/*!sc*/
# .gwvqVZ.active{color:#2B2B2B;background-color:#F2F2F2;border-color:#2B2B2B;}/*!sc*/
# .gwvqVZ.disabled{color:#A0A0A0;background-color:#F2F2F2;border-color:#A0A0A0;box-shadow:none;}/*!sc*/
# .ierfjE{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;background-image:none;cursor:pointer;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;font-weight:500;gap:8px;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;line-height:1;touch-action:manipulation;-webkit-transition:background-color 100ms cubic-bezier(0.5,0,0.2,1),color 100ms cubic-bezier(0.5,0,0.2,1),border-color 100ms cubic-bezier(0.5,0,0.2,1);transition:background-color 100ms cubic-bezier(0.5,0,0.2,1),color 100ms cubic-bezier(0.5,0,0.2,1),border-color 100ms cubic-bezier(0.5,0,0.2,1);-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;white-space:nowrap;vertical-align:middle;font-size:16px;border-radius:40px;border:1px solid transparent;-webkit-text-decoration:none;text-decoration:none;height:36px;padding:0 16px;color:#2B2B2B;background-color:#FFFFFF;border-color:#2B2B2B;}/*!sc*/
# .ierfjE.disabled{cursor:not-allowed;}/*!sc*/
# .ierfjE false @media (hover:hover) and (pointer:fine):hover{-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .ierfjE:focus{-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .ierfjE:focus:not(:focus-visible){outline:none;}/*!sc*/
# @media (hover:hover) and (pointer:fine){.ierfjE:hover{color:#646464;background-color:#F2F2F2;border-color:#646464;}}/*!sc*/
# .ierfjE:focus{color:#2B2B2B;}/*!sc*/
# .ierfjE.active{color:#2B2B2B;background-color:#F2F2F2;border-color:#2B2B2B;}/*!sc*/
# .ierfjE.disabled{color:#A0A0A0;background-color:#F2F2F2;border-color:#A0A0A0;}/*!sc*/
# .xIHco{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;background-image:none;cursor:pointer;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;font-weight:500;gap:8px;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;line-height:1;touch-action:manipulation;-webkit-transition:background-color 100ms cubic-bezier(0.5,0,0.2,1),color 100ms cubic-bezier(0.5,0,0.2,1),border-color 100ms cubic-bezier(0.5,0,0.2,1);transition:background-color 100ms cubic-bezier(0.5,0,0.2,1),color 100ms cubic-bezier(0.5,0,0.2,1),border-color 100ms cubic-bezier(0.5,0,0.2,1);-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;white-space:nowrap;vertical-align:middle;font-size:16px;border-radius:40px;border:1px solid transparent;-webkit-text-decoration:none;text-decoration:none;height:48px;padding:0 24px;margin-right:6px;color:#2B2B2B;background-color:#FFFFFF;border-color:#2B2B2B;}/*!sc*/
# .xIHco.disabled{cursor:not-allowed;}/*!sc*/
# .xIHco false @media (hover:hover) and (pointer:fine):hover{-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .xIHco:focus{-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .xIHco:focus:not(:focus-visible){outline:none;}/*!sc*/
# @media (hover:hover) and (pointer:fine){.xIHco:hover{color:#646464;background-color:#F2F2F2;border-color:#646464;}}/*!sc*/
# .xIHco:focus{color:#2B2B2B;}/*!sc*/
# .xIHco.active{color:#2B2B2B;background-color:#F2F2F2;border-color:#2B2B2B;}/*!sc*/
# .xIHco.disabled{color:#A0A0A0;background-color:#F2F2F2;border-color:#A0A0A0;}/*!sc*/
# .hsshIA{-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;background-image:none;cursor:pointer;display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;font-weight:500;gap:8px;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;line-height:1;touch-action:manipulation;-webkit-transition:background-color 100ms cubic-bezier(0.5,0,0.2,1),color 100ms cubic-bezier(0.5,0,0.2,1),border-color 100ms cubic-bezier(0.5,0,0.2,1);transition:background-color 100ms cubic-bezier(0.5,0,0.2,1),color 100ms cubic-bezier(0.5,0,0.2,1),border-color 100ms cubic-bezier(0.5,0,0.2,1);-webkit-user-select:none;-moz-user-select:none;-ms-user-select:none;user-select:none;vertical-align:middle;font-size:16px;border-radius:40px;border:1px solid transparent;-webkit-text-decoration:none;text-decoration:none;height:36px;border-radius:0;border:0;padding:0;text-align:left;-webkit-text-decoration:underline;text-decoration:underline;color:#2B2B2B;background-color:transparent;border-color:transparent;}/*!sc*/
# .hsshIA.disabled{cursor:not-allowed;}/*!sc*/
# @media (hover:hover) and (pointer:fine){.hsshIA:hover{-webkit-text-decoration:underline;text-decoration:underline;}}/*!sc*/
# .hsshIA:focus{-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .hsshIA:focus:not(:focus-visible){outline:none;}/*!sc*/
# @media (hover:hover) and (pointer:fine){.hsshIA:hover{color:#646464;background-color:transparent;border-color:transparent;}}/*!sc*/
# .hsshIA:focus{color:#2B2B2B;}/*!sc*/
# .hsshIA.active{color:#646464;background-color:transparent;border-color:transparent;}/*!sc*/
# .hsshIA.disabled{color:#A0A0A0;background-color:transparent;border-color:transparent;}/*!sc*/
# ...
# .kyqWvy::-webkit-scrollbar{-webkit-appearance:none;border-left:1px solid #CACACA;}/*!sc*/
# .kyqWvy::-webkit-scrollbar-thumb{border-radius:16px;background-color:#CACACA;border:3px solid transparent;background-clip:content-box;}/*!sc*/
# .kyqWvy .filter-dropdown-body{padding:16px;}/*!sc*/
# .kyqWvy .filter-dropdown-footer{background-color:#FFFFFF;border-top:1px solid #757575;bottom:auto;position:static;}/*!sc*/
# .duMFdT{background-color:#FFFFFF;border:1px solid #757575;border-radius:16px;box-shadow:0px 4px 16px rgba(0,0,0,0.16);box-sizing:border-box;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;overflow:hidden;width:375px;}/*!sc*/
# .duMFdT::-webkit-scrollbar{-webkit-appearance:none;border-left:1px solid #CACACA;}/*!sc*/
# .duMFdT::-webkit-scrollbar-thumb{border-radius:16px;background-color:#CACACA;border:3px solid transparent;background-clip:content-box;}/*!sc*/
# .duMFdT .filter-dropdown-body{padding:16px;}/*!sc*/
# .duMFdT .filter-dropdown-footer{background-color:#FFFFFF;border-top:1px solid #757575;bottom:auto;position:static;}/*!sc*/
# data-styled.g288[id="FilterDropdownMenustyles__StyledFilterDropdownMenu-rui__caveff-0"]{content:"bCnSa-D,kyqWvy,duMFdT,"}/*!sc*/
# .XKwQI{width:100%;display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;-webkit-box-pack:justify;-webkit-justify-content:space-between;-ms-flex-pack:justify;justify-content:space-between;}/*!sc*/
# .XKwQI .heading{white-space:nowrap;}/*!sc*/
# .XKwQI .divider{line-height:1;text-overflow:ellipsis;white-space:nowrap;overflow:hidden;}/*!sc*/
# .XKwQI button:focus:not(:focus-visible){outline:none;}/*!sc*/
# data-styled.g289[id="FilterDropdownHeaderstyles__StyledFilterDropdownHeaderContainer-rui__sc-74qprl-0"]{content:"XKwQI,"}/*!sc*/
# .bQAcJB{position:relative;max-width:180px;min-width:auto;padding-right:32px;}/*!sc*/
# @media (hover:hover) and (pointer:fine){.bQAcJB:hover{color:#646464;background-color:#F2F2F2;border-color:#646464;}}/*!sc*/
# .bQAcJB .filter-btn-icon,.bQAcJB .filter-reset-btn{position:absolute;top:50%;-webkit-transform:translateY(-50%);-ms-transform:translateY(-50%);transform:translateY(-50%);outline-offset:2px;border-radius:50%;}/*!sc*/
# .bQAcJB .filter-btn-icon{pointer-events:none;right:'1px';}/*!sc*/
# .bQAcJB .filter-reset-btn{right:'4px';}/*!sc*/
# data-styled.g290[id="FilterDropdownTogglestyles__StyledDropdownToggle-rui__sc-15uokj2-0"]{content:"bQAcJB,"}/*!sc*/
# .gTBIPE{overflow:hidden;}/*!sc*/
# .gTBIPE .slick-arrow{cursor:pointer;}/*!sc*/
# .gTBIPE .slick-initialized{visibility:visible;}/*!sc*/
# .gTBIPE .slick-list{margin:0 -8px;}/*!sc*/
# .gTBIPE .slick-disabled{display:none !important;}/*!sc*/
# .gTBIPE .slick-track{display:-webkit-box !important;display:-webkit-flex !important;display:-ms-flexbox !important;display:flex !important;width:100% !important;}/*!sc*/
# .gTBIPE .slick-slide{float:none !important;height:auto !important;}/*!sc*/
# .gTBIPE .slick-slide > div{height:100%;}/*!sc*/
# data-styled.g291[id="HorizontalTileSliderstyles__StyledSliderWrapper-rui__l1he7-0"]{content:"gTBIPE,"}/*!sc*/
# .ozaAl{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;position:relative;-webkit-box-pack:center;-webkit-justify-content:center;-ms-flex-pack:center;justify-content:center;-webkit-align-items:center;-webkit-box-align:center;-ms-flex-align:center;align-items:center;width:191px;min-height:86px;height:100%;padding:8px 6px;text-align:center;border:8px solid #FFFFFF;border-radius:calc(16px * 2);cursor:pointer;background:#2B2B2B;-webkit-text-decoration:none;text-decoration:none;}/*!sc*/
# .ozaAl span{position:relative;z-index:1;color:#FFFFFF;}/*!sc*/
# .ozaAl:before,.ozaAl:after{content:'';display:block;height:100%;width:100%;position:absolute;left:0;bottom:0;border-radius:16px;overflow:hidden;}/*!sc*/
# .ozaAl:after{background-color:#000000;opacity:0.5;}/*!sc*/
# @media (hover:hover) and (pointer:fine){.ozaAl:hover{color:#FFFFFF;-webkit-text-decoration:none;text-decoration:none;}}/*!sc*/
# .ozaAl:focus:not(:focus-visible){outline:none;}/*!sc*/
# data-styled.g292[id="HorizontalTileSliderstyles__StyledTile-rui__l1he7-1"]{content:"ozaAl,"}/*!sc*/
# .eiXzCt > h2{margin-bottom:8px;}/*!sc*/
# .eiXzCt .search-summary-control-link{margin-top:16px;margin-right:auto;}/*!sc*/
# .eiXzCt .search-summary-collapse h3{font-size:16px;margin:16px 0;}/*!sc*/
# .eiXzCt .summary-link-list{-webkit-column-count:1;column-count:1;padding-left:0;list-style:none;}/*!sc*/
# .eiXzCt .summary-link-list li{margin-bottom:8px;}/*!sc*/
# @media (min-width:480px){.eiXzCt .summary-link-list{-webkit-column-count:2;column-count:2;}}/*!sc*/
# @media (min-width:768px){.eiXzCt .summary-link-list{-webkit-column-count:3;column-count:3;}}/*!sc*/
# data-styled.g293[id="SearchSummaryWidgetstyles__StyledSearchSummaryWidget-rui__sc-56k7qk-0"]{content:"eiXzCt,"}/*!sc*/
# .ixcScZ .pre-approved-widget-image-wrapper{padding-bottom:50%;overflow:hidden;position:relative;margin:0 0 16px;}/*!sc*/
# .ixcScZ .pre-approved-widget-image-wrapper img{position:absolute;top:50%;width:100%;-webkit-transform:translate(0,-50%);-ms-transform:translate(0,-50%);transform:translate(0,-50%);}/*!sc*/
# data-styled.g294[id="PreApprovedWidgetstyles__StyledPreApprovedWidget-rui__vo2wch-0"]{content:"ixcScZ,"}/*!sc*/
# .drptor video{margin-bottom:16px;}/*!sc*/
# .drptor .label-bottom{line-height:1.1;margin-bottom:8px;-webkit-text-decoration:underline;text-decoration:underline;}/*!sc*/
# .drptor .label-bottom a{font-size:16px;white-space:normal;line-height:20px;}/*!sc*/
# .drptor .description a{display:-webkit-inline-box;display:-webkit-inline-flex;display:-ms-inline-flexbox;display:inline-flex;}/*!sc*/
# data-styled.g295[id="VideoWidgetstyles__StyledVideoWidget-rui__sc-195xuio-0"]{content:"drptor,"}/*!sc*/
# .jLrZsN{text-align:center;width:100%;display:none;}/*!sc*/
# @media (min-width:768px){.jLrZsN{min-height:90px;margin-top:16px;margin-bottom:16px;display:block;}}/*!sc*/
# .poPni{text-align:center;width:100%;display:none;}/*!sc*/
# @media (min-width:768px){.poPni{min-height:90px;margin-top:16px;margin-bottom:16px;display:none;}}/*!sc*/
# data-styled.g297[id="sc-AxjAm"]{content:"jLrZsN,poPni,"}/*!sc*/
# @media (min-width:768px){.bjYcLx{display:none;}}/*!sc*/
# @supports (-webkit-touch-callout:none){.bjYcLx[data-ios-chrome='0']{display:none;}}/*!sc*/
# data-styled.g298[id="styles__StyledMobileBanner-sc-1mjf4fr-0"]{content:"bjYcLx,"}/*!sc*/
# .fbBRoL{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;min-height:100vh;}/*!sc*/
# .fbBRoL .main-container{display:-webkit-box;display:-webkit-flex;display:-ms-flexbox;display:flex;-webkit-flex-direction:column;-ms-flex-direction:column;flex-direction:column;-webkit-flex:1 0 auto;-ms-flex:1 0 auto;flex:1 0 auto;}/*!sc*/
# .fbBRoL .footer{-webkit-flex-shrink:0;-ms-flex-negative:0;flex-shrink:0;}/*!sc*/
# data-styled.g299[id="styles__StyledAppShell-sc-1a4hn7f-0"]{content:"fbBRoL,"}/*!sc*/
# @-webkit-keyframes fEWCgj{0%{-webkit-transform:rotate(0deg);-ms-transform:rotate(0deg);transform:rotate(0deg);}100%{-webkit-transform:rotate(360deg);-ms-transform:rotate(360deg);transform:rotate(360deg);}}/*!sc*/
# @keyframes fEWCgj{0%{-webkit-transform:rotate(0deg);-ms-transform:rotate(0deg);transform:rotate(0deg);}100%{-webkit-transform:rotate(360deg);-ms-transform:rotate(360deg);transform:rotate(360deg);}}/*!sc*/
# data-styled.g403[id="sc-keyframes-fEWCgj"]{content:"fEWCgj,"}/*!sc*/
# .ReactModal__Body--open{overflow:hidden;}/*!sc*/
# data-styled.g404[id="sc-global-WcUdU1"]{content:"sc-global-WcUdU1,"}/*!sc*/
# .ReactModal__Body--open{overflow:hidden;}/*!sc*/
# data-styled.g405[id="sc-global-WcUdU2"]{content:"sc-global-WcUdU2,"}/*!sc*/
# .ReactModal__Body--open{overflow:hidden;}/*!sc*/
# data-styled.g406[id="sc-global-WcUdU3"]{content:"sc-global-WcUdU3,"}/*!sc*/
# </style></head><body><div data-reactroot="" id="__next"><div class="styles__StyledAppShell-sc-1a4hn7f-0 fbBRoL"><div class="main-container"><div class="sc-AxjAm jLrZsN ad-wrapper lb1-ad" id="lb1_container_srp" visibility="block"><div class="ads" data-testid="div-gpt-ad-LB1-SRP" id="div-gpt-ad-LB1-SRP"></div></div><div class="sc-AxjAm poPni ad-wrapper lb1-ad" id="lb1_container" visibility="none"><div class="ads" data-testid="div-gpt-ad-LB1" id="div-gpt-ad-LB1"></div></div><div class="MobileBannerstyles__StyledMobileBanner-rui__sc-1udwx2o-0 brcRvz styles__StyledMobileBanner-sc-1mjf4fr-0 bjYcLx" data-ios-chrome="0"><button aria-label="Close" class="styles__StyledCloseButton-rui__z6l2vv-0 kjUHJl close-icon" data-testid="close-button" reversed=""></button><svg aria-hidden="true" class="app-icon" data-testid="core-icon" focusable="false" style="display:inline-block;width:1em;height:1em;font-size:40px;color:#FFFFFF;fill:currentColor" viewbox="0 0 24 24"><path clip-rule="evenodd" d="M12.01 2.5 22 12.712h-3.047v9.163h-13.9v-9.163H2L12.01 2.5Zm2.618 7.13c.508 0 .93.144 1.193.406.25.276.37.604.363 1.01 0 .597-.376 1.194-1.088 1.194-.719 0-.97-.446-1.147-.866-.152-.367-.29-.597-.502-.597-.553 0-1.404 1.253-1.622 2.814-.02.25-.046.82-.046 1.41v1.955c0 1.115.119 1.574.31 1.98.132.243.257.375.402.427.198.085.343.111.541.131l.086.007v.275H8.264v-.275l.093-.007c.224-.026.422-.079.58-.15.284-.145.422-.276.554-.703.072-.439.086-1.095.086-1.574v-4.69c0-.354 0-1.18-.066-1.462a.825.825 0 0 0-.37-.57c-.23-.165-.48-.19-.745-.21l-.085-.007v-.275h3.25c.172 0 .251.118.251.23a71.547 71.547 0 0 1-.024 1.212l-.015.729c.342-.919.758-1.391 1.12-1.739l.007-.006c.363-.302.89-.65 1.728-.65Z" fill="#fff" fill-rule="evenodd"></path></svg><div class="headlines"><div class="base__StyledType-rui__sc-108xfm0-0 hhZQzR title">Realtor.com® Real Estate App</div><span class="reviews"><div aria-label="4.5 out of 5 stars" class="StarRatingsstyles__StyledStarRatings-rui__sc-1ftq0cx-0 jzPUG ratings" role="img"><svg aria-hidden="true" data-testid="icon-star-filled" focusable="false" style="display:inline-block;width:1em;height:1em;font-size:16px;color:#F4B630;fill:currentColor" viewbox="0 0 24 24"><path d="m14.642 4.07 1.467 2.973 3.281.477c2.417.35 3.382 3.32 1.633 5.025l-2.374 2.314.56 3.268c.413 2.407-2.113 4.242-4.275 3.106L12 19.69l-2.934 1.543c-2.162 1.136-4.688-.7-4.275-3.106l.56-3.268-2.374-2.314C1.228 10.841 2.193 7.871 4.61 7.52l3.28-.477L9.359 4.07c1.08-2.19 4.203-2.19 5.284 0Z"></path></svg><svg aria-hidden="true" data-testid="icon-star-filled" focusable="false" style="display:inline-block;width:1em;height:1em;font-size:16px;color:#F4B630;fill:currentColor" viewbox="0 0 24 24"><path d="m14.642 4.07 1.467 2.973 3.281.477c2.417.35 3.382 3.32 1.633 5.025l-2.374 2.314.56 3.268c.413 2.407-2.113 4.242-4.275 3.106L12 19.69l-2.934 1.543c-2.162 1.136-4.688-.7-4.275-3.106l.56-3.268-2.374-2.314C1.228 10.841 2.193 7.871 4.61 7.52l3.28-.477L9.359 4.07c1.08-2.19 4.203-2.19 5.284 0Z"></path></svg><svg aria-hidden="true" data-testid="icon-star-filled" focusable="false" style="display:inline-block;width:1em;height:1em;font-size:16px;color:#F4B630;fill:currentColor" viewbox="0 0 24 24"><path d="m14.642 4.07 1.467 2.973 3.281.477c2.417.35 3.382 3.32 1.633 5.025l-2.374 2.314.56 3.268c.413 2.407-2.113 4.242-4.275 3.106L12 19.69l-2.934 1.543c-2.162 1.136-4.688-.7-4.275-3.106l.56-3.268-2.374-2.314C1.228 10.841 2.193 7.871 4.61 7.52l3.28-.477L9.359 4.07c1.08-2.19 4.203-2.19 5.284 0Z"></path></svg><svg aria-hidden="true" data-testid="icon-star-filled" focusable="false" style="display:inline-block;width:1em;height:1em;font-size:16px;color:#F4B630;fill:currentColor" viewbox="0 0 24 24"><path d="m14.642 4.07 1.467 2.973 3.281.477c2.417.35 3.382 3.32 1.633 5.025l-2.374 2.314.56 3.268c.413 2.407-2.113 4.242-4.275 3.106L12 19.69l-2.934 1.543c-2.162 1.136-4.688-.7-4.275-3.106l.56-3.268-2.374-2.314C1.228 10.841 2.193 7.871 4.61 7.52l3.28-.477L9.359 4.07c1.08-2.19 4.203-2.19 5.284 0Z"></path></svg> ...
#           window.__OPTIMIZELY_CACHE_ENTRIES__={"SRP_RERANK_EXPERIMENT-undefined-{}":{"isEnabled":false,"variables":{"EXPERIMENT_KEY":"PLATFORMS_SRP_RANKING_AA_082023_FT","FEATURE_KEY":"PLATFORMS_SRP_RANKING_AA_082023"}},"PLATFORMS_SRP_RANKING_AA_082023-PLATFORMS_SRP_RANKING_AA_082023_FT-{}":{"isEnabled":false,"variables":{"Bucket_Values":{"sort":"fractal_v1.1.3"}},"variation":null},"PLATFORMS_SRP_RANKING_AA_082023-Bucket_Values-json-{}":{"sort":"fractal_v1.1.3"},"ccx_map_tiger_lvt-CCX_MAP_TIGER_LVT-{}":{"isEnabled":false,"variables":{"Variation":""},"variation":null},"ccx_map_tiger_lvt_mweb-CCX_MAP_TIGER_LVT_MWEB-{}":{"isEnabled":false,"variables":{"Variation":""},"variation":null},"ccx_map_tiger_mvt-CCX_MAP_TIGER_MVT-{}":{"isEnabled":false,"variables":{"Variation":""},"variation":null},"CCX_HP_SAVESEARCH_CONV_FEATURE-CCX_HP_SAVESEARCH_CONV_TEST_202306-{}":{"isEnabled":false,"variables":{},"variation":null},"rn_srp_relevance_ranking_022023-rn_srp_relevance_ranking_022023_ft-{}":{"isEnabled":false,"variables":{"Variation":{"model":"rentalModelV2_1","business_logic":"costar_basic"}},"variation":null},"FOR_SALE_SRP_TWO_TAP-FOR_SALE_SRP_TWO_TAP_202211-{}":{"isEnabled":false,"variables":{"Variation":"C"},"variation":null},"FOR_SALE_SRP_FILTER_REDESIGN-FOR_SALE_SRP_FILTER_REDESIGN-{}":{"isEnabled":false,"variables":null,"variation":null},"RN_SRP_SHARE_RESULTS-RN_SRP_SHARE_RESULTS_202302-{}":{"isEnabled":false,"variables":{"Variation":"C"},"variation":null},"RN_RENT_OPEN_LDP_FROM_SRP_NEW_TAB-RN_RENT_OPEN_LDP_FROM_SRP_NEW_TAB_202304-{}":{"isEnabled":true,"variables":{},"variation":"V1"},"RN_SRP_RELEVANCE_RANKING_0723-RN_SRP_RELEVANCE_RANKING_0723_FT-{}":{"isEnabled":false,"variables":{"Variation":""},"variation":null},"MEDIA_SRP_NEW_CONSTRUCTION-MEDIA_SRP_NEW_CONSTRUCTION_202303-{}":{"isEnabled":true,"variables":{"Variation":"V1"},"variation":"V1"},"MEDIA_RENTAL_SRP_GOOGLE_ADSENSE-MEDIA_RENTAL_SRP_GOOGLE_ADSENSE_202304-{}":{"isEnabled":false,"variables":{"Variation":""},"variation":null},"cube_intersection_observer_mobile-cube_intersection_observer_mobile_test-{}":{"isEnabled":false,"variables":{},"variation":null},"media_ads_tiger_loading_cards-media_ads_tiger_loading_tile_card-{}":{"isEnabled":false,"variables":{},"variation":null},"cube_intersection_observer_desktop-cube_intersection_observer_desktop_test-{}":{"isEnabled":false,"variables":{},"variation":null},"ads_tiger_fetch_priority-ads_tiger_fetch_priority_test-{}":{"isEnabled":false,"variables":{},"variation":null},"MEDIA_RENTAL_SRP_GOOGLE_ADSENSE_SWITCH-{}":false,"MEDIA_SRP_ADHESION_MWEB_SWITCH_202212-{}":true,"CCX_SRP_LISTING_PROMOTIONS-undefined-{}":{"isEnabled":true,"variables":{"LISTING_PROMOTION_VALUES":{"slots":[5,6,7,8],"city_promotion_name":"CITY","postal_promotion_name":"POSTALCODE"}}},"RN_PROMO_FILTER-{}":true,"RN_PINNED_LDP-{}":true,"WEBP_RAAS_LOADED_ON_EVENT-{}":true,"WEBP_CUSTOM_RDC_LOGO-undefined-{}":{"isEnabled":true,"variables":{"C":"rdc-logo-default"}},"BX_BSS_ADD_RELEASES-{}":false,"bx_medallia_test-{}":true,"bx_cobuyer_nudge_global_header-{}":false,"RN_RENT_TO_OWN_RDC_SEARCH-{}":false,"FS_SRP_LDP_SPA-{}":true,"cx_fs_srp_ldp_spa_scroll_restoration-{}":false,"nh_builder_filter-{}":false,"NH_COMM_CAROUSEL_PROMO-{}":true,"RDCX_FULLSTORY-{}":true,"ENABLE_SRP_FULLSTORY-{}":false,"WEB_PUSH-{}":true,"INLINE_ADS_2022-{}":true,"RN_SHOW_AVAIL_ATTRIBUTION-{}":true,"NHC_BUILDER_PROMOTION_ENABLED-{}":false,"FEEDBACK_FORM_WILDFIRE_RISK-{}":false}
#           window.__OPTIMIZELY_INITIAL_PROPS__={"isDisabled":false,"userId":"af50a1df-96f5-40aa-a147-13046fed8e74","attributes":{"origin":"x-web:realestateandhomes-search"},"userAgent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0.0.0 Safari/537.36","queryParams":{"slug":["Texas"]},"project":"RDCX","env":"production","enableHoldouts":false}
#           </script></body></html>

# %% [markdown]
# ### Results

# %%
results = soup.find_all('div', {'class' : 'BasePropertyCard_propertyCard__JXqlE'})

# %%
len(results)
# Out:
# 42

# %% [markdown]
# ### Target necessary data

# %% [markdown]
# - title
# - address
# - bed
# - bath
# - price
# - property_link

# %% [markdown]
# #### title

# %%
results[0].find('div', {'data-testid' : 'card-description'}).get_text()
# Out:
# 'For Sale'

# %% [markdown]
# #### address

# %%
results[0].find('div', {'class' : 'content-col-left'}).get_text()
# Out:
# '3441 Loop 1781 # 4DRockport, TX 78382'

# %% [markdown]
# #### bed

# %%
results[0].find('ul', {'data-testid' : 'card-meta'}).findChildren('span')[0].get_text().replace('+','')
# Out:
# '4'

# %% [markdown]
# #### bath

# %%
results[0].find('ul', {'data-testid' : 'card-meta'}).findChildren('span')[1].get_text()
# Out:
# '3'

# %% [markdown]
# #### price

# %%
results[0].find('div', {'class' : 'price-wrapper'}).findChildren('div')[0].get_text().replace('$','').replace(',','')
# Out:
# '432500'

# %% [markdown]
# #### property link

# %%
results[0].find('a', {'class' : 'LinkComponent_anchor__2uAhr'}).get('href')
# Out:
# '/realestateandhomes-detail/3441-Loop-1781-Unit-4D_Rockport_TX_78382_M98510-56670?from=srp-list-card'

# %% [markdown]
# ### append 2 links

# %%
root_link = 'https://www.realtor.com'

# %% [markdown]
# #### append property link

# %%
property_link_partial = []
property_link_joined = []

for link_property in soup.findChildren('a', {'class' : 'LinkComponent_anchor__2uAhr'}):
    x = link_property.get('href')
    property_link_partial.append(x)
    
for link in property_link_partial:
    property_link_joined.append(urllib.parse.urljoin(root_link, link))

# %%
property_link_joined
# Out:
# ['https://www.realtor.com/realestateandhomes-detail/3441-Loop-1781-Unit-4D_Rockport_TX_78382_M98510-56670?from=srp-list-card',
#  'https://www.realtor.com/realestateandhomes-detail/3441-Loop-1781-Unit-4D_Rockport_TX_78382_M98510-56670?from=srp-list-card',
#  'https://www.realtor.com/realestateandhomes-detail/116-Trail-Wood_New-Braunfels_TX_78130_M96844-97202?from=srp-list-card',
#  'https://www.realtor.com/realestateandhomes-detail/116-Trail-Wood_New-Braunfels_TX_78130_M96844-97202?from=srp-list-card',
#  'https://www.realtor.com/realestateandhomes-detail/5793-Highway-361-Park-53-Rd-Unit-314_Port-Aransas_TX_78373_M98666-70381?from=srp-list-card',
#  'https://www.realtor.com/realestateandhomes-detail/5793-Highway-361-Park-53-Rd-Unit-314_Port-Aransas_TX_78373_M98666-70381?from=srp-list-card',
#  'https://www.realtor.com/realestateandhomes-detail/An-County-Road-3855-Lot-101_Palestine_TX_75801_M99115-34254?from=srp-list-card',
#  'https://www.realtor.com/realestateandhomes-detail/An-County-Road-3855-Lot-101_Palestine_TX_75801_M99115-34254?from=srp-list-card',
#  'https://www.realtor.com/realestateandhomes-detail/3209-Erwin-Dr_Plano_TX_75074_M75237-33697?from=srp-list-card',
#  'https://www.realtor.com/realestateandhomes-detail/3209-Erwin-Dr_Plano_TX_75074_M75237-33697?from=srp-list-card',
#  'https://www.realtor.com/realestateandhomes-detail/1217-Harbor-Lights-Dr_Corpus-Christi_TX_78412_M96878-41003?from=srp-list-card',
#  'https://www.realtor.com/realestateandhomes-detail/1217-Harbor-Lights-Dr_Corpus-Christi_TX_78412_M96878-41003?from=srp-list-card',
#  'https://www.realtor.com/realestateandhomes-detail/725-County-Road-112_George-West_TX_78022_M98086-30244?from=srp-list-card',
#  'https://www.realtor.com/realestateandhomes-detail/725-County-Road-112_George-West_TX_78022_M98086-30244?from=srp-list-card',
#  'https://www.realtor.com/realestateandhomes-detail/735-King-Arthur-Ct_Scroggins_TX_75480_M96166-01478?from=srp-list-card',
#  'https://www.realtor.com/realestateandhomes-detail/735-King-Arthur-Ct_Scroggins_TX_75480_M96166-01478?from=srp-list-card',
#  'https://www.realtor.com/realestateandhomes-detail/5908-140th-St_Lubbock_TX_79424_M97962-35456?from=srp-list-card',
#  'https://www.realtor.com/realestateandhomes-detail/5908-140th-St_Lubbock_TX_79424_M97962-35456?from=srp-list-card',
#  'https://www.realtor.com/realestateandhomes-detail/6172-Farm-to-Market-119_Dumas_TX_79029_M96780-33504?from=srp-list-card',
#  'https://www.realtor.com/realestateandhomes-detail/6172-Farm-to-Market-119_Dumas_TX_79029_M96780-33504?from=srp-list-card']

# %% [markdown]
# ### Put everything together inside a For-Loop

# %%
title = []
address = []
bed = []
bath = []
price = []
property_link = []

root_link = 'https://www.realtor.com'

for result in results:
    
    #title
    title.append(result.find('div', {'data-testid' : 'card-description'}).get_text())
    
    #address
    address.append(result.find('div', {'class' : 'content-col-left'}).get_text())
                   
    #bed
    try:
        bed.append(float(result.find('ul', {'data-testid' : 'card-meta'}).findChildren('span')[0].get_text()))
    except:
        bed.append(0)
    #bath
    try:
        bath.append(float(result.find('ul', {'data-testid' : 'card-meta'}).findChildren('span')[1].get_text().replace('+','')))
    except:
        bath.append(0)
    
    #price
    price.append(float(result.find('div', {'class' : 'price-wrapper'}).findChildren('div')[0].get_text().replace('$','').replace(',','')))
    
    #property_link
    property_link=property_link_joined

# %%
title
# Out:
# ['For Sale',
#  'For Sale',
#  'For Sale',
#  'For Sale',
#  'For Sale',
#  'For Sale',
#  'For Sale',
#  'For Sale',
#  'For Sale',
#  'For Sale',
#  'For Sale',
#  'For Sale',
#  'For Sale',
#  'For Sale',
#  'For Sale',
#  'For Sale',
#  'For Sale',
#  'For Sale',
#  'For Sale',
#  'For Sale',
#  'For Sale',
#  'For Sale',
#  'For Sale',
#  'For Sale',
#  'For Sale',
#  'For Sale',
#  'For Sale',
#  'For Sale',
#  'For Sale',
#  'For Sale',
#  'For Sale',
#  'For Sale',
#  'For Sale',
#  'For Sale',
#  'For Sale',
#  'For Sale',
#  'For Sale',
#  'For Sale',
#  'For Sale',
#  'For Sale',
#  'For Sale',
#  'For Sale']

# %% [markdown]
# ### Create Pandas Dataframe

# %%
df_realtor_realestate = pd.DataFrame({'title':title, 'address':address, 'bedrooms':bed, 'bathrooms':bath, 'price_$':price})

# %%
df_realtor_realestate
# Out:
#        title                                         address       bedrooms  \
# 0   For Sale                31037 King TerBulverde, TX 78163              5
# 1   For Sale            15200 Kent Justin DrAustin, TX 78725              4
# 2   For Sale    19923 Pennybacker Bridge DrCypress, TX 77433              3
# 3   For Sale                  315 N HeltonRandolph, TX 75475              3
# 4   For Sale            1306 County Road 415Merkel, TX 79536              4
# 5   For Sale                  2770 Wilson RdPalmer, TX 75152              3
# 6   For Sale         111 Clopton Lake RdWaxahachie, TX 75165              2
# 7   For Sale        63259 State Highway 132 NLytle, TX 78052              2
# 8   For Sale           2386 Santa Maria LnRobstown, TX 78380              3
# 9   For Sale             7038 Cole Creek DrHouston, TX 77092              3
# 10  For Sale  3214 Casa De Palmas DrCorpus Christi, TX 78411              4
# 11   Pending              209 W Nichols AveDickens, TX 79243              2
# 12  For Sale                     StephensonAnahuac, TX 77514  8,102sqft lot
# 13  For Sale                   156 Park AveStaples, TX 78670              4
# 14   Pending       E County Road 1110 Lot 1Riviera, TX 78379  39.41acre lot
# 15  For Sale           17851 Lone Ranch RdAmarillo, TX 79124              4
# 16  For Sale              289 Dorris RdBrownsville, TX 78526    197acre lot
# 17  For Sale             9229 Alaska RdBrownsville, TX 78521              4
# 18  For Sale                   728 Jones AveSeguin, TX 78155              3
# 19  For Sale      312 Sauder Farms RdNew Braunfels, TX 78130              3
# 20  For Sale      15610 Whispering Green DrCypress, TX 77429              4
# 21  For Sale                        Fm 2919Beasley, TX 77417  76.42acre lot
# 22   Pending                 1012 Old Park RdEnnis, TX 75119  18.35acre lot
# 23  For Sale          5061 County Road 4010Decatur, TX 76234              3
# 24  For Sale           4106 Brook Shadow DrHouston, TX 77345              4
# 25  For Sale       1775 N Service Rd # 3611Winters, TX 79567              4
# 26  For Sale          County Road 212Hallettsville, TX 77964   14.7acre lot
# 27  For Sale                       109 Oak StEarly, TX 76802              3
# 28  For Sale           10535 Springcroft CtHelotes, TX 78023              5
# 29   Pending           10 Balmoral PlThe Woodlands, TX 77382              4
# 30  For Sale                780 Club Lake RdNocona, TX 76255              3
# 31  For Sale                 201 W Morris StYoakum, TX 77995              5
# 32  For Sale                 Willis WaukeganConroe, TX 77303      5acre lot
# 33  For Sale                   501 Herman StHumble, TX 77338              3
# 34  For Sale                    100 Elk DrLongview, TX 75605              4
# 35  For Sale                     0003 Ella LnElgin, TX 78621   1.39acre lot
# 36  For Sale       1080 An County Road 1224Elkhart, TX 75839              2
# 37  For Sale                1216 Rountree CtCelina, TX 75009              4
# 38  For Sale   2611 Pennsylvania AveLaguna Heights, TX 78578              3
# 39  For Sale           5815 Preston WayColleyville, TX 76034              4
# 40  For Sale         1431 Gribble Springs RdSanger, TX 76266   9.94acre lot
# 41  For Sale            1014 County Road 1235Savoy, TX 75479              2
#
#     bathrooms     price_$
# 0        4.50    839900.0
# 1        2.50    489000.0
# 2        2.50    405000.0
# 3        2.00    254999.0
# 4        3.50    889000.0
# 5        2.50    699000.0
# 6        2.00    748000.0
# 7        1.00    368000.0
# 8        2.50    575000.0
# 9        2.00    295000.0
# 10       2.50    349900.0
# 11       2.00     33500.0
# 12       0.00     23500.0
# 13       3.00    529000.0
# 14      39.41    300000.0
# 15       3.00    399000.0
# 16     197.00  12900000.0
# 17       4.50    750000.0
# 18       1.00    152000.0
# 19       2.00    220000.0
# 20       2.50    339000.0
# 21      76.42   2695000.0
# 22      18.35    375000.0
# 23       2.00    350000.0
# 24       2.00    335000.0
# 25       3.00   1500000.0
# 26      14.70    399500.0
# 27       3.00    275000.0
# 28       4.00    698250.0
# 29       4.50   1285000.0
# 30       2.00    459000.0
# 31       4.00    149000.0
# 32       5.00    465000.0
# 33       2.00    324900.0
# 34       3.50    799000.0
# 35       1.39    169900.0
# 36       2.00    210000.0
# 37       2.00    419900.0
# 38       2.50    264900.0
# 39       5.50   1999000.0
# 40       9.94    499000.0
# 41       1.00    295000.0

# %% [markdown]
# ### Output in Excel

# %%
df_realtor_realestate.to_excel('realtor estate single.xlsx', index=False)

# %% [markdown]
# ### Part 2 - Pagination - Scrape 50 Pages

# %%
title = []
address = []
bed = []
bath = []
price = []



for i in range (1,51):
    header = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/115.0.0.0 Safari/537.36'}
    
    website = 'https://www.realtor.com/realestateandhomes-search/Texas/pg-' + str (i)

    response = requests.get(website, headers=header)

    soup = BeautifulSoup(response.content, 'html.parser')
    
    results = soup.find_all('div', {'class' : 'BasePropertyCard_propertyCard__JXqlE'})
    
    
for result in results:
    
    #title
    try:
        title.append(result.find('div', {'data-testid' : 'card-description'}).get_text())
    except:
        title.append('')
        
    #address
    try:
        address.append(result.find('div', {'class' : 'content-col-left'}).get_text())
    except:
        address.append('')
        
    #bed
    try:
        bed.append(result.find('ul', {'data-testid' : 'card-meta'}).findChildren('span')[0].get_text())
    except:
        bed.append(0)
        
    #bath
    try:
        bath.append(float(result.find('ul', {'data-testid' : 'card-meta'}).findChildren('span')[1].get_text().replace('+','')))
    except:
        bath.append(0)
        
    #price
    try:
        price.append(float(result.find('div', {'class' : 'price-wrapper'}).findChildren('div')[0].get_text().replace('$','').replace(',','')))
    except:
        price.append(0)
    
    
df_realtor_realestate_multiple = pd.DataFrame({'title':title, 'address':address, 'bedrooms':bed, 'bathrooms':bath, 'price':price })
df_realtor_realestate_multiple
# Out:
#        title                                         address       bedrooms  \
# 0   For Sale                31037 King TerBulverde, TX 78163              5
# 1   For Sale            15200 Kent Justin DrAustin, TX 78725              4
# 2   For Sale    19923 Pennybacker Bridge DrCypress, TX 77433              3
# 3   For Sale                  315 N HeltonRandolph, TX 75475              3
# 4   For Sale            1306 County Road 415Merkel, TX 79536              4
# 5   For Sale                  2770 Wilson RdPalmer, TX 75152              3
# 6   For Sale         111 Clopton Lake RdWaxahachie, TX 75165              2
# 7   For Sale        63259 State Highway 132 NLytle, TX 78052              2
# 8   For Sale           2386 Santa Maria LnRobstown, TX 78380              3
# 9   For Sale             7038 Cole Creek DrHouston, TX 77092              3
# 10  For Sale  3214 Casa De Palmas DrCorpus Christi, TX 78411              4
# 11   Pending              209 W Nichols AveDickens, TX 79243              2
# 12  For Sale                     StephensonAnahuac, TX 77514  8,102sqft lot
# 13  For Sale                   156 Park AveStaples, TX 78670              4
# 14   Pending       E County Road 1110 Lot 1Riviera, TX 78379  39.41acre lot
# 15  For Sale           17851 Lone Ranch RdAmarillo, TX 79124              4
# 16  For Sale              289 Dorris RdBrownsville, TX 78526    197acre lot
# 17  For Sale             9229 Alaska RdBrownsville, TX 78521              4
# 18  For Sale                   728 Jones AveSeguin, TX 78155              3
# 19  For Sale      312 Sauder Farms RdNew Braunfels, TX 78130              3
# 20  For Sale      15610 Whispering Green DrCypress, TX 77429              4
# 21  For Sale                        Fm 2919Beasley, TX 77417  76.42acre lot
# 22   Pending                 1012 Old Park RdEnnis, TX 75119  18.35acre lot
# 23  For Sale          5061 County Road 4010Decatur, TX 76234              3
# 24  For Sale           4106 Brook Shadow DrHouston, TX 77345              4
# 25  For Sale       1775 N Service Rd # 3611Winters, TX 79567              4
# 26  For Sale          County Road 212Hallettsville, TX 77964   14.7acre lot
# 27  For Sale                       109 Oak StEarly, TX 76802              3
# 28  For Sale           10535 Springcroft CtHelotes, TX 78023              5
# 29   Pending           10 Balmoral PlThe Woodlands, TX 77382              4
# 30  For Sale                780 Club Lake RdNocona, TX 76255              3
# 31  For Sale                 201 W Morris StYoakum, TX 77995              5
# 32  For Sale                 Willis WaukeganConroe, TX 77303      5acre lot
# 33  For Sale                   501 Herman StHumble, TX 77338              3
# 34  For Sale                    100 Elk DrLongview, TX 75605              4
# 35  For Sale                     0003 Ella LnElgin, TX 78621   1.39acre lot
# 36  For Sale       1080 An County Road 1224Elkhart, TX 75839              2
# 37  For Sale                1216 Rountree CtCelina, TX 75009              4
# 38  For Sale   2611 Pennsylvania AveLaguna Heights, TX 78578              3
# 39  For Sale           5815 Preston WayColleyville, TX 76034              4
# 40  For Sale         1431 Gribble Springs RdSanger, TX 76266   9.94acre lot
# 41  For Sale            1014 County Road 1235Savoy, TX 75479              2
#
#     bathrooms       price
# 0        4.50    839900.0
# 1        2.50    489000.0
# 2        2.50    405000.0
# 3        2.00    254999.0
# 4        3.50    889000.0
# 5        2.50    699000.0
# 6        2.00    748000.0
# 7        1.00    368000.0
# 8        2.50    575000.0
# 9        2.00    295000.0
# 10       2.50    349900.0
# 11       2.00     33500.0
# 12       0.00     23500.0
# 13       3.00    529000.0
# 14      39.41    300000.0
# 15       3.00    399000.0
# 16     197.00  12900000.0
# 17       4.50    750000.0
# 18       1.00    152000.0
# 19       2.00    220000.0
# 20       2.50    339000.0
# 21      76.42   2695000.0
# 22      18.35    375000.0
# 23       2.00    350000.0
# 24       2.00    335000.0
# 25       3.00   1500000.0
# 26      14.70    399500.0
# 27       3.00    275000.0
# 28       4.00    698250.0
# 29       4.50   1285000.0
# 30       2.00    459000.0
# 31       4.00    149000.0
# 32       5.00    465000.0
# 33       2.00    324900.0
# 34       3.50    799000.0
# 35       1.39    169900.0
# 36       2.00    210000.0
# 37       2.00    419900.0
# 38       2.50    264900.0
# 39       5.50   1999000.0
# 40       9.94    499000.0
# 41       1.00    295000.0
